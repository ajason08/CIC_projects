# %%
import sys 
print (sys.version)
# Out:
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]

# %%
def rem_digits(s):
    return re.sub(r'\b\d+\b','',s)

# %%
import string
import re
table = str.maketrans({k: None for k in string.punctuation})
## l = [rem_digits(c).translate(table).lower() for c in tr_dict[()]['1500'][1][0].split()]
## l = list(filter(None, l))

# %%
# top_300w = {}
# for k in tr_dict[()].keys():
#     top_300w[k] = []
#     l = [rem_digits(j).translate(table).lower() for i in tr_dict[()][k][1] for j in i.split()]
#     l = list(filter(None,l))
#     l = l[:300]
#     top_300w[k].append(tr_dict[()][k][0])
#     top_300w[k].append(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7a799f656c46> in <module>
#       1 top_300w = {}
# ----> 2 for k in tr_dict[()].keys():
#       3     top_300w[k] = []
#       4     l = [rem_digits(j).translate(table).lower() for i in tr_dict[()][k][1] for j in i.split()]
#       5     l = list(filter(None,l))
#
# NameError: name 'tr_dict' is not defined

# %%
# dev_top_300w = {}
# for k in dev_dict[()].keys():
#     dev_top_300w[k] = []
#     l = [rem_digits(j).translate(table).lower() for i in dev_dict[()][k][1] for j in i.split()]
#     l = list(filter(None,l))
#     l = l[:300]
#     dev_top_300w[k].append(dev_dict[()][k][0])
#     dev_top_300w[k].append(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-41fe4b35cc14> in <module>
#       1 dev_top_300w = {}
# ----> 2 for k in dev_dict[()].keys():
#       3     dev_top_300w[k] = []
#       4     l = [rem_digits(j).translate(table).lower() for i in dev_dict[()][k][1] for j in i.split()]
#       5     l = list(filter(None,l))
#
# NameError: name 'dev_dict' is not defined

# %%
import csv
with open('tr_top_300w.csv', 'w') as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerow(('fn', 'label', 'content'))
    writer.writerows(zip(top_300w.keys(), lab, txt))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-be35d276435b> in <module>
#       3     writer = csv.writer(f, delimiter='\t')
#       4     writer.writerow(('fn', 'label', 'content'))
# ----> 5     writer.writerows(zip(top_300w.keys(), lab, txt))
#
# NameError: name 'lab' is not defined

# %%
import pandas as pd

# %%
# !head -n 2 dev_conc.csv
# Out:
# fn,category,concepts
# 1599,G,bn:00000489n bn:00022379n bn:14623232n bn:15125301n bn:00079373n bn:00046920n bn:17348611n bn:00054625n bn:00082924v bn:00079373n bn:00026716n bn:00079373n bn:00022379n bn:14623232n bn:15125301n bn:00054625n bn:00083187v bn:00091124v bn:00108815a bn:00046920n bn:00026716n bn:00045816n bn:00025314n bn:00079373n bn:00026716n bn:00079373n bn:00022379n bn:14623232n bn:15125301n bn:00084080v bn:00046920n bn:00021961n bn:00079373n bn:00026716n bn:00046920n bn:15125301n bn:00001287n bn:00066357n bn:00045816n bn:00025314n bn:00047730n bn:00066574n bn:00025333n bn:00066574n bn:00083187v bn:01215351n bn:00047730n bn:00083240v bn:00000759n bn:00025314n bn:00109740a bn:00079373n bn:00026716n bn:00109740a bn:00079373n bn:00022379n bn:14623232n bn:15125301n bn:00085769v bn:00108815a bn:00046920n bn:00026716n bn:00021961n bn:00046920n bn:00034369n bn:00022379n bn:14623232n bn:15125301n bn:00079373n bn:00046920n bn:00023946n bn:00023960n bn:00054390n bn:02439331n bn:00005095n bn:00027489n bn:00100144a bn:00073217n bn:00007228n bn:00050828n bn:00060986n bn:00005095n bn:00116472r bn:00088167v bn:00082575v bn:00089663v bn:00054390n bn:00034265n bn:00021551n bn:00108977a bn:00021551n bn:00083240v bn:00054625n bn:00082924v bn:00079373n bn:00026716n bn:00079373n bn:00022379n bn:14623232n bn:15125301n bn:
# 0    2226     G  ['abstract', 'systems', 'and', 'methods', 'to'...
# 1    1653     H  ['abstract', 'embodiments', 'of', 'the', 'pres...
# 2    3684     F  ['burner', 'tube', 'for', 'gas', 'grill', 'abs...
# 3     477     G  ['abstract', 'a', 'method', 'of', 'determining...
# 4    2112     G  ['abstract', 'of', 'the', 'disclosure', 'this'...
# 5    2945     F  ['piston', 'arrangement', 'abstract', 'a', 'pi...
# 6    3927     H  ['abstract', 'loudspeakers', 'are', 'described...
# 7    3279     B  ['abstract', 'a', 'spare', 'wheel', 'carrier',...
# 8    1390     C  ['fusion', 'proteins', 'comprising', 'an', 'en...
# 9    3546     A  ['abstract', 'disclosed', 'herein', 'compositi...
# 10   3661     G  ['abstract', 'a', 'method', 'of', 'encrypting'...
# 11    104     C  ['abstract', 'novel', 'thionocarbamate', 'comp...
# 12    901     C  ['abstract', 'perforin', 'p2', 'is', 'expresse...
# 13    380     F  ['engine', 'specific', 'assembly', 'stand', 'm...
# 14    723     C  ['llszpinterwovennrportbldccszp162977031docx',...
# 15   3405     G  ['abstract', 'methods', 'systems', 'and', 'app...
# 16   1293     A  ['abstract', 'the', 'invention', 'relates', 't...
# 17    414     B  ['abstract', 'a', 'system', 'is', 'provided', ...
# 18   3815     H  ['abstract', 'methods', 'systems', 'and', 'app...
# 19    399     E  ['abstract', 'of', 'the', 'disclosure', 'a', '...
# 20   2538     C  ['cyclosporine', 'a', 'form', 'and', 'method',...
# 21    959     E  ['abstract', 'a', 'lock', 'cylinder', 'having'...
# 22    737     B  ['abstract', 'this', 'invention', 'relates', '...
# 23   2871     G  ['abstract', 'this', 'invention', 'relates', '...
# 24   3963     B  ['abstract', 'a', 'pneumatic', 'tool', 'includ...
# 25   1159     A  ['abstract', 'whole', 'clump', 'mechanical', '...
# 26    835     A  ['abstract', 'a', 'gaming', 'system', 'compris...
# 27   2570     C  ['abstract', 'an', 'improved', 'process', 'for...
# 28    564     A  ['abstract', 'oral', 'formulations', 'provided...
# 29   1182     C                         ['na', 'parse', 'failure']
# ..    ...   ...                                                ...
# 765  2300     B  ['lubrication', 'of', 'transfer', 'plates', 'u...
# 766  3842     C  ['abstract', 'a', 'vaccine', 'for', 'the', 'tr...
# 767  2518     H  ['pwo', 'abstract', 'a', 'door', 'for', 'a', '...
# 768  3474     C  ['abstract', 'the', 'present', 'invention', 'g...
# 769  3154     E  ['frameless', 'glass', 'fencing', 'component',...
# 770  1908     A  ['abstract', 'a', 'gaming', 'system', 'compris...
# 771   771     C  ['abstract', 'the', 'invention', 'provides', '...
# 772  1416     A  ['abstract', 'methods', 'are', 'presented', 'f...
# 773  3780     G  ['systems', 'and', 'methods', 'for', 'synchron...
# 774   872     F  ['abstract', 'a', 'discharge', 'head', 'featur...
# 775   767     C  ['abstract', 'the', 'present', 'invention', 'p...
# 776  3401     G  ['abstract', 'the', 'present', 'application', ...
# 777  1957     E  ['supportweight', 'strengthening', 'post', 're...
# 778   298     G  ['abstract', 'systems', 'and', 'processes', 'f...
# 779  1308     H  ['abstract', 'a', 'method', 'and', 'apparatus'...
# 780  1829     A  ['dermal', 'filler', 'compositions', 'includin...
# 781  3440     C  ['abstract', 'in', 'a', 'first', 'aspect', 'th...
# 782   542     B  ['abstract', 'a', 'truck', 'body', 'structure'...
# 783   407     H  ['abstract', 'a', 'mobivisor', 'is', 'a', 'pho...
# 784  1977     G  ['abstract', 'contact', 'lenses', 'incorporate...
# 785   844     H  ['abstract', 'a', 'method', 'for', 'creating',...
# 786  3157     A  ['abstract', 'the', 'present', 'disclosure', '...
# 787  3140     E  ['abstract', 'a', 'multiuse', 'block', 'includ...
# 788  2219     G  ['abstract', 'a', 'method', 'of', 'gaming', 'i...
# 789  3491     A  ['abstract', 'a', 'handheld', 'massage', 'tool...
# 790  1387     G  ['abstract', 'methods', 'systems', 'and', 'com...
# 791   504     C  ['abstract', 'provided', 'herein', 'is', 'a', ...
# 792   963     C  ['abstract', 'the', 'invention', 'concerns', '...
# 793   349     G  ['abstract', 'this', 'invention', 'relates', '...
# 794  3603     B  ['abstract', 'a', 'variable', 'stiffness', 'go...
#
# [795 rows x 3 columns]

# %%
dev_df.columns = ['fn','category', 'content']

# %%
dev_df.set_index(['fn','category'], inplace=True)
dev_conc_df.set_index(['fn','category'], inplace=True)

# %%
len(tr_conc_df.loc[16, 'G'][0])
# Out:
# 13974

# %%
dev_df = dev_df.join(dev_conc_df)

# %%
dev_df.to_csv('dev_300W_conc.csv')

# %%
import pandas as pd
tr_df = pd.read_csv('tr_300W_conc.csv')

# %%
tr_df.loc[tr_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, fn, category, content, concept]
# Index: []

# %%
tr_df = tr_df.drop(['Unnamed: 0'], axis=1)

# %%
dev_df.columns = ['fn','category','content', 'concept']

# %%
len(tr_df)
# Out:
# 3174

# %%
tr_df.to_csv('tr_300W_conc.csv', index=False)

# %%
df = pd.read_csv('dev_top_300w.csv', header=None, delimiter='\\t')
# Out:
# /media/backup/segun/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
# !head  -n 2 tr_300W_conc.csv
# Out:
# head: cannot open 'tr_300W_conc.csv' for reading: No such file or directory

# %%
import string
def tokenizer(s):
#     table = str.maketrans({k: None for k in string.punctuation})
#     return [w.translate(table) for w in s[1:-1].split()]
    s = s.replace('#', ' ')
    return [w for w in s.split()]
def tokenizer1(s):
    return [w for w in s.split('#')] #if w.endswith('n')]

# %%
import torchtext
from torchtext import data

txt_field = data.Field(sequential=True, tokenize=tokenizer, include_lengths=True, use_vocab=True)
label_field = data.Field(sequential=False, use_vocab=True, pad_token=None, unk_token=None)
conc_field = data.Field(sequential=True, tokenize=tokenizer1, include_lengths=True, use_vocab=True)

tr_dev_fields = [('fn', None), ('category', label_field), ('concepts', conc_field), ('nouns', txt_field)]
train, val = data.TabularDataset.splits(path='./', format='csv', train='tr_pat_ns_concs.csv', validation='dev_pat_ns_concs.csv', fields=tr_dev_fields, skip_header=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0e57523c624a> in <module>
# ----> 1 import torchtext
#       2 from torchtext import data
#       3
#       4 txt_field = data.Field(sequential=True, tokenize=tokenizer, include_lengths=True, use_vocab=True)
#       5 label_field = data.Field(sequential=False, use_vocab=True, pad_token=None, unk_token=None)
#
# ModuleNotFoundError: No module named 'torchtext'

# %%
from torchtext import vocab
w_vec = vocab.Vectors('patent-100.vec','../pat')
c_vec = vocab.Vectors('nasari_patents.vec','../pat')

# %%
txt_field.build_vocab(train, val, vectors=w_vec) #max_size=100000,
conc_field.build_vocab(train, val, vectors=c_vec)
label_field.build_vocab(train)

# %%
txt_field.vocab.vectors.shape, txt_field.vocab.vectors[txt_field.vocab.stoi['of']]
# Out:
# (torch.Size([51910, 100]),
#  tensor([-0.0637,  0.1496,  0.0241, -0.3208,  0.1110,  0.1083,  0.0079, -0.0349,
#           0.1214,  0.2693,  0.0310, -0.0729,  0.0032, -0.0871, -0.1437,  0.0367,
#           0.2025, -0.0113,  0.0004,  0.2847,  0.0292, -0.0697, -0.1006,  0.1520,
#          -0.0384, -0.2338,  0.1285, -0.0816, -0.4201, -0.0241, -0.0043,  0.0240,
#          -0.4045, -0.2258, -0.0943,  0.1011,  0.2357, -0.3172,  0.2305,  0.2976,
#          -0.3410,  0.3293, -0.0097,  0.1463,  0.1125,  0.0586,  0.2135, -0.1591,
#          -0.2013, -0.0323,  0.1086, -0.4197, -0.2009, -0.0531,  0.0016,  0.1789,
#           0.0410,  0.1157,  0.1397, -0.1334,  0.2085, -0.2894,  0.1633,  0.1999,
#          -0.0762, -0.2183, -0.0862,  0.2136, -0.1474, -0.0696,  0.1988, -0.0072,
#           0.0631,  0.0137,  0.1054,  0.1477,  0.2719, -0.1809,  0.0645,  0.0881,
#          -0.1371,  0.1351, -0.2000,  0.1060, -0.1877,  0.0823,  0.0846, -0.0321,
#          -0.1533, -0.1853, -0.1189, -0.3900,  0.1782,  0.1433,  0.0759, -0.0610,
#          -0.3339,  0.0169, -0.1899, -0.3463]))

# %%
conc_field.vocab.stoi
# Out:
# defaultdict(<function torchtext.vocab._default_unk_index>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              'bn:00021551n': 2,
#              'bn:00007436n': 3,
#              'bn:00034369n': 4,
#              'bn:00026716n': 5,
#              'bn:00054625n': 6,
#              'bn:00075759n': 7,
#              'bn:00032099n': 8,
#              'bn:00021394n': 9,
#              'bn:00005095n': 10,
#              'bn:00021395n': 11,
#              'bn:00079373n': 12,
#              'bn:00075373n': 13,
#              'bn:00061746n': 14,
#              'bn:00025314n': 15,
#              'bn:00030718n': 16,
#              'bn:00021497n': 17,
#              'bn:00054390n': 18,
#              'bn:00006382n': 19,
#              'bn:00071431n': 20,
#              'bn:00062704n': 21,
#              'bn:00077270n': 22,
#              'bn:00034004n': 23,
#              'bn:00053801n': 24,
#              'bn:00011744n': 25,
#              'bn:00037180n': 26,
#              'bn:00050828n': 27,
#              'bn:00000902n': 28,
#              'bn:00006484n': 29,
#              'bn:00017027n': 30,
#              'bn:00027489n': 31,
#              'bn:00021398n': 32,
#              'bn:00054416n': 33,
#              'bn:15125301n': 34,
#              'bn:00033729n': 35,
#              'bn:00022071n': 36,
#              'bn:00061017n': 37,
#              'bn:00042379n': 38,
#              'bn:00035426n': 39,
#              'bn:00027546n': 40,
#              'bn:00072760n': 41,
#              'bn:00022283n': 42,
#              'bn:00021961n': 43,
#              'bn:00005092n': 44,
#              'bn:00080386n': 45,
#              'bn:00003341n': 46,
#              'bn:00026512n': 47,
#              'bn:00070190n': 48,
#              'bn:00034265n': 49,
#              'bn:00005927n': 50,
#              'bn:00021464n': 51,
#              'bn:00054018n': 52,
#              'bn:00018101n': 53,
#              'bn:00020452n': 54,
#              'bn:00052556n': 55,
#              'bn:00041942n': 56,
#              'bn:00008781n': 57,
#              'bn:00025965n': 58,
#              'bn:00017761n': 59,
#              'bn:00058285n': 60,
#              'bn:00079675n': 61,
#              'bn:00005004n': 62,
#              'bn:00026638n': 63,
#              'bn:00035778n': 64,
#              'bn:00071525n': 65,
#              'bn:00064855n': 66,
#              'bn:00060986n': 67,
#              'bn:00035370n': 68,
#              'bn:00021221n': 69,
#              'bn:00045970n': 70,
#              'bn:00036182n': 71,
#              'bn:00009477n': 72,
#              'bn:00007781n': 73,
#              'bn:00075330n': 74,
#              'bn:00037382n': 75,
#              'bn:01215351n': 76,
#              'bn:00046698n': 77,
#              'bn:00021644n': 78,
#              'bn:00070574n': 79,
#              'bn:00047235n': 80,
#              'bn:00024712n': 81,
#              'bn:00001972n': 82,
#              'bn:00005513n': 83,
#              'bn:00030850n': 84,
#              'bn:00017026n': 85,
#              'bn:00016401n': 86,
#              'bn:00004629n': 87,
#              'bn:00028638n': 88,
#              'bn:00044489n': 89,
#              'bn:00058442n': 90,
#              'bn:00076457n': 91,
#              'bn:00077386n': 92,
#              'bn:00026501n': 93,
#              'bn:00036821n': 94,
#              'bn:00075142n': 95,
#              'bn:00051760n': 96,
#              'bn:00079508n': 97,
#              'bn:00000488n': 98,
#              'bn:00022129n': 99,
#              'bn:00035324n': 100,
#              'bn:00046705n': 101,
#              'bn:00015180n': 102,
#              'bn:00002185n': 103,
#              'bn:00078798n': 104,
#              'bn:00079106n': 105,
#              'bn:00044916n': 106,
#              'bn:00021483n': 107,
#              'bn:00047087n': 108,
#              'bn:00064536n': 109,
#              'bn:00060767n': 110,
#              'bn:00061135n': 111,
#              'bn:00003268n': 112,
#              'bn:00046848n': 113,
#              'bn:00075652n': 114,
#              'bn:00009635n': 115,
#              'bn:03303891n': 116,
#              'bn:00007228n': 117,
#              'bn:00063110n': 118,
#              'bn:00060377n': 119,
#              'bn:00069078n': 120,
#              'bn:00051288n': 121,
#              'bn:00027670n': 122,
#              'bn:00059125n': 123,
#              'bn:00015914n': 124,
#              'bn:00019262n': 125,
#              'bn:00059303n': 126,
#              'bn:00030820n': 127,
#              'bn:00080831n': 128,
#              'bn:00020872n': 129,
#              'bn:00000753n': 130,
#              'bn:00060799n': 131,
#              'bn:00026107n': 132,
#              'bn:00034205n': 133,
#              'bn:00011308n': 134,
#              'bn:00021751n': 135,
#              'bn:16111634n': 136,
#              'bn:00026817n': 137,
#              'bn:01244302n': 138,
#              'bn:00018115n': 139,
#              'bn:01220982n': 140,
#              'bn:00077585n': 141,
#              'bn:00013142n': 142,
#              'bn:01641329n': 143,
#              'bn:00042526n': 966,
#              'bn:00068672n': 967,
#              'bn:03295461n': 968,
#              'bn:00015056n': 969,
#              'bn:00054304n': 970,
#              'bn:00025719n': 971,
#              'bn:00076333n': 972,
#              'bn:00001276n': 973,
#              'bn:00081492n': 974,
#              'bn:00014137n': 975,
#              'bn:00030627n': 976,
#              'bn:00064426n': 977,
#              'bn:03253409n': 978,
#              'bn:14227259n': 979,
#              'bn:00007329n': 980,
#              'bn:00046891n': 981,
#              'bn:00056135n': 982,
#              'bn:00017984n': 983,
#              'bn:00029192n': 984,
#              'bn:00044910n': 985,
#              'bn:00066884n': 986,
#              'bn:00025928n': 987,
#              'bn:00071215n': 988,
#              'bn:00377649n': 989,
#              'bn:01541423n': 990,
#              'bn:00061054n': 991,
#              'bn:16781388n': 992,
#              'bn:00012484n': 993,
#              'bn:00044408n': 994,
#              'bn:00002216n': 995,
#              'bn:00025467n': 996,
#              'bn:00001191n': 997,
#              'bn:00012902n': 998,
#              'bn:00046961n': 999,
#              ...})

# %%
import torch
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# %%
traindl, valdl = data.BucketIterator.splits(datasets=(train, val), batch_sizes=(5,3), sort_key=lambda x: (len(x.nouns),len(x.concepts)), device=device, sort_within_batch=True, repeat=False)

# %%
batch = next(iter(traindl))

# %%
x, l = batch.nouns

# %%
l
# Out:
# tensor([674, 674, 674, 673, 673], device='cuda:1')

# %%
class BatchGenerator:
    def __init__(self,dl, x_wfield, x_cfield, y_field):
        self.dl, self.x_wfield, self.x_cfield, self.y_field = dl, x_wfield, x_cfield, y_field
    def __len__(self):
        return len(self.dl)
    def __iter__(self):
        for b in self.dl:
            xw = getattr(b, self.x_wfield)
            xc = getattr(b, self.x_cfield)
            y = getattr(b, self.y_field)
            yield((xw, xc), y)

# %%
train_batch_it = BatchGenerator(traindl, 'nouns', 'concepts','category')

# %%
x,y = next(iter(train_batch_it))

# %%
w, c =x

# %%
torch.sort(c[1], descending=True)[0]
# Out:
# tensor([670, 668, 640, 624, 611], device='cuda:1')

# %%
del m

# %%
wvocab_sz = len(txt_field.vocab)
wemb_dim = 100
cvocab_sz = len(conc_field.vocab)
cemb_dim = 300

n_hidden = 64
n_out = len(label_field.vocab)

# %%
import torch
import torch.nn as nn
SEED = 789 #123456
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
class ConcatPoolingGRU(nn.Module):
    def __init__(self, wvocab_sz, wemb_dim,cvocab_sz, cemb_dim, n_hidden, n_out, wpre_vec, cpre_vec,bidirectional=True):
        super().__init__()
        self.wvocab_sz = wvocab_sz
        self.cvocab_sz = cvocab_sz
        self.wemb_dim = wemb_dim
        self.cemb_dim = cemb_dim
        self.n_hidden = n_hidden
        self.n_out = n_out
        self.bidirectional = bidirectional
        self.wemb = nn.Embedding(self.wvocab_sz, self.wemb_dim)
        self.wemb.weight.data.copy_(wpre_vec)
        self.wemb.weight.requires_grad = False
        self.cemb = nn.Embedding(self.cvocab_sz, self.cemb_dim)
        self.cemb.weight.data.copy_(cpre_vec)
        self.cemb.weight.requires_grad = False
        self.wgru = nn.GRU(self.wemb_dim,self.n_hidden, bidirectional=bidirectional)
        self.cgru = nn.GRU(self.cemb_dim,self.n_hidden, bidirectional=bidirectional)
        self.lin1 = nn.Linear(300, self.n_hidden)
        self.nlin1 = nn.ReLU()
        self.drop = nn.Dropout(0.1)
        if bidirectional:
            self.out = nn.Linear(self.n_hidden*2*2, self.n_out)
        else:
            self.out = nn.Linear(self.n_hidden*4, self.n_out)
            
    def forward(self, seq):
#         bs = seq.size(1)
        w_seq, c_seq = seq
        w_seq,wl_seq = w_seq
        wl_seq, _ = torch.sort(wl_seq, descending=True)
#         print(wl_seq)
        c_seq,cl_seq = c_seq
        bs = w_seq.size(1)
        self.hw = self.init_hidden(bs)
        self.hc = self.init_hidden(bs)
        
        w_seq = w_seq.transpose(0,1)
        c_seq = c_seq.transpose(0,1)
        
        wembs = self.wemb(w_seq)
        wembs = wembs.transpose(0,1)
        wembs = nn.utils.rnn.pack_padded_sequence(wembs, wl_seq)
        
        cembs = self.cemb(c_seq)
#         cembs = cembs.transpose(0,1)
#         cembs = nn.utils.rnn.pack_padded_sequence(cembs, torch.sort(cl_seq, descending=True)[0])
        cembs = cembs.mean(dim=1)
#         print(cembs.shape)
        cembs = self.lin1(cembs)
        cembs = self.drop(cembs)
        cembs = self.nlin1(cembs)
        
        cembs = cembs.view(bs,-1)
#         cembs = cembs.transpose(0,1)
        wgru_out, self.hw = self.wgru(wembs, self.hw)
        wgru_out, _ = nn.utils.rnn.pad_packed_sequence(wgru_out)
#         print(self.hw.shape)
#         cgru_out, self.hc = self.cgru(cembs, self.hc)
#         cgru_out, _ = nn.utils.rnn.pad_packed_sequence(cgru_out)
        
        wavg_pool = nn.functional.adaptive_avg_pool1d(wgru_out.permute(1,2,0),1).view(bs, -1)
        wmax_pool = nn.functional.adaptive_avg_pool1d(wgru_out.permute(1,2,0),1).view(bs,-1)
        wmax_pool = self.drop(wmax_pool)
        wmax_pool = self.nlin1(wmax_pool)
        wavg_pool = self.drop(wavg_pool)
        wavg_pool = self.nlin1(wavg_pool)
#         cavg_pool = nn.functional.adaptive_avg_pool1d(cgru_out.permute(1,2,0),1).view(bs,-1)
#         cmax_pool = nn.functional.adaptive_avg_pool1d(cgru_out.permute(1,2,0),1).view(bs,-1)
        
        outp = self.out(torch.cat([torch.squeeze(self.hw),wavg_pool,wmax_pool,cembs],dim=1))
        return nn.functional.log_softmax(outp, dim=-1)
        
    def init_hidden(self, batch_sz):
        if self.bidirectional:
            return torch.zeros(2, batch_sz, self.n_hidden).to(device)
        else:
            return torch.zeros(1,batch_sz, self.n_hidden).to(device)

# %%
traindl, valdl = data.BucketIterator.splits(datasets=(train, val), batch_sizes=(8,16), sort_key=lambda x:(len(x.nouns),len(x.concepts)), device=device, sort_within_batch=True,repeat=False)
train_batch_it = BatchGenerator(traindl,'nouns','concepts','category')
val_batch_it = BatchGenerator(valdl, 'nouns','concepts','category')
m = ConcatPoolingGRU(wvocab_sz,wemb_dim,cvocab_sz,cemb_dim, n_hidden, n_out, train.fields['nouns'].vocab.vectors,train.fields['concepts'].vocab.vectors, bidirectional=False).to(device)
opt = torch.optim.Adam(filter(lambda p: p.requires_grad, m.parameters()), 1e-2)
criterion = nn.NLLLoss()
# fit model with ignite

# %%
from ignite.engine import Engine, Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import Accuracy, Loss, RunningAverage, Precision, Recall, MetricsLambda
from ignite.handlers import ModelCheckpoint,  EarlyStopping
from ignite.contrib.handlers import ProgressBar
# def process_function(engine, batch):
#     m.train()
#     optimizer.zero_grad()
#     x, y = batch.content, batch.label
#     y_pred = m(x)
#     loss = criterion(y_pred, y)
#     loss.backward()
#     opt.step()
#     return loss.item()

# def eval_function(engine, batch):
#     m.eval()
#     with torch.no_grad():
#         x, y = batch.content, batch.label
#         y_pred = m(x)
#         return y_pred, y
    
# trainer = Engine(process_function)
precision = Precision(average=False)
recall = Recall(average=False)
F1 = precision*recall*2/(precision+recall+1e-20)
F1 = MetricsLambda(lambda t: torch.mean(t).item(), F1)
trainer = create_supervised_trainer(m, opt, criterion)
# train_evaluator = Engine(eval_function)
evaluator = create_supervised_evaluator(m, metrics={'accuracy':Accuracy(),'nll': Loss(criterion), 'f1':F1})
# validation_evaluator = Engine(eval_function)

# RunningAverage(output_transform=lambda x: x).attach(trainer, 'loss')

# @trainer.on(Events.ITERATION_COMPLETED)
# def log_training_loss(trainer):
#     print("Epoch[{}] Loss: {:.2f}".format(trainer.state.epoch, trainer.state.output))

@trainer.on(Events.EPOCH_COMPLETED)
def log_training_results(trainer):
    evaluator.run(train_batch_it)
    metrics = evaluator.state.metrics
    print("Training Results - Epoch: {}  Avg accuracy: {:.2f} Avg loss: {:.2f} f1: {:.2f}"
          .format(trainer.state.epoch, metrics['accuracy'], metrics['nll'], metrics['f1']))

@trainer.on(Events.EPOCH_COMPLETED)
def log_validation_results(trainer):
    evaluator.run(val_batch_it)
    metrics = evaluator.state.metrics
    print("Validation Results - Epoch: {}  Avg accuracy: {:.2f} Avg loss: {:.2f} f1: {:.2f}"
          .format(trainer.state.epoch, metrics['accuracy'], metrics['nll'], metrics['f1']))

trainer.run(train_batch_it, max_epochs=5)
# Out:
# Training Results - Epoch: 1  Avg accuracy: 0.69 Avg loss: 0.82 f1: 0.56
# Validation Results - Epoch: 1  Avg accuracy: 0.69 Avg loss: 0.89 f1: 0.56
# Training Results - Epoch: 2  Avg accuracy: 0.76 Avg loss: 0.64 f1: 0.65
# Validation Results - Epoch: 2  Avg accuracy: 0.72 Avg loss: 0.77 f1: 0.59
# Training Results - Epoch: 3  Avg accuracy: 0.80 Avg loss: 0.56 f1: 0.77
# Validation Results - Epoch: 3  Avg accuracy: 0.72 Avg loss: 0.77 f1: 0.67
# Training Results - Epoch: 4  Avg accuracy: 0.80 Avg loss: 0.52 f1: 0.72
# Validation Results - Epoch: 4  Avg accuracy: 0.70 Avg loss: 0.87 f1: 0.59
# Training Results - Epoch: 5  Avg accuracy: 0.81 Avg loss: 0.52 f1: 0.82
# Validation Results - Epoch: 5  Avg accuracy: 0.70 Avg loss: 0.93 f1: 0.65

# %%
train_batch_it

# %%
s = "#water content#content#weight#weight#air#oxidation#haircolor"
s.split('#')
