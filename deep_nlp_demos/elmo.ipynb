# %%
import sys
#!{sys.executable} -m pip install pandas
{sys.executable}
# Out:
# {'/home/jason/anaconda3/envs/tf_env/envs/allennlp/bin/python'}

# %%
from allennlp.commands import elmo

elmo_ins = elmo.ElmoEmbedder(options_file='https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway_5.5B/elmo_2x4096_512_2048cnn_2xhighway_5.5B_options.json', 
    weight_file='https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway_5.5B/elmo_2x4096_512_2048cnn_2xhighway_5.5B_weights.hdf5'
                            )
mytext = "Sitting at the bar of the Four Seasons restaurant , architect William McDonough seems oblivious to the glamorous clientele and the elegant setting ."
tokens= mytext.split()
#tokens = ["I", "ate", "an", "apple", "for", "breakfast"]
vectors = elmo_ins.embed_sentence(tokens)

assert(len(vectors) == 3) # one for each layer in the ELMo output
assert(len(vectors[0]) == len(tokens))
# Out:
# 01/22/2019 18:13:27 - INFO - allennlp.commands.elmo -   Initializing ELMo.

# %%
print (type(vectors[0][0]))
# Out:
# <class 'numpy.ndarray'>

# %%
import scipy
scipy.spatial.distance.cosine(vectors[2][3], vectors2[2][3]) # cosine distance between "apple" and "carrot" in the last layer
# Out:
# 0.18020612001419067

# %%
mytext= "Still, all this comes nearly a year and a half after Philip Pizzo of the National Cancer Institute offered evidence that AZT could reverse the ravages of AIDS dementia, sometimes prompting dramatic recovery of IQ levels and reappearance of lost motor skills. Since then, roughly 50 pediatric patients have received the drug in his program"
mytext = mytext.split(".")
mytext = [sent.split() for sent in mytext]
for sent in mytext: 
    print (sent)
    for i,token in enumerate(sent):
        print(i,token)
iterable_sent = iter(mytext)
vector_sents = elmo.embed_sentences(iterable_sent)
vector_sents = list(vector_sents)
print(vector_sents[0][0][7])
print(vector_sents[1][0][9])
print(vector_sents[0][1][7])
print(vector_sents[1][1][9])
print(vector_sents[0][2][7])
print(vector_sents[1][2][9])
# Out:
# ['Still,', 'all', 'this', 'comes', 'nearly', 'a', 'year', 'and', 'a', 'half', 'after', 'Philip', 'Pizzo', 'of', 'the', 'National', 'Cancer', 'Institute', 'offered', 'evidence', 'that', 'AZT', 'could', 'reverse', 'the', 'ravages', 'of', 'AIDS', 'dementia,', 'sometimes', 'prompting', 'dramatic', 'recovery', 'of', 'IQ', 'levels', 'and', 'reappearance', 'of', 'lost', 'motor', 'skills']
# 0 Still,
# 1 all
# 2 this
# 3 comes
# 4 nearly
# 5 a
# 6 year
# 7 and
# 8 a
# 9 half
# 10 after
# 11 Philip
# 12 Pizzo
# 13 of
# 14 the
# 15 National
# 16 Cancer
# 17 Institute
# 18 offered
# 19 evidence
# 20 that
# 21 AZT
# 22 could
# 23 reverse
# 24 the
# 25 ravages
# 26 of
# 27 AIDS
# 28 dementia,
# 29 sometimes
# 30 prompting
# 31 dramatic
# 32 recovery
# 33 of
# 34 IQ
# 35 levels
# 36 and
# 37 reappearance
# 38 of
# 39 lost
# 40 motor
# 41 skills
# ['Since', 'then,', 'roughly', '50', 'pediatric', 'patients', 'have', 'received', 'the', 'drug', 'in', 'his', 'program']
# 0 Since
# 1 then,
# 2 roughly
# ...

# %%
recovery = scipy.spatial.distance.cosine(vector_sents[0][2][32], vector_sents[1][2][5])
aids = scipy.spatial.distance.cosine(vector_sents[0][2][27], vector_sents[1][2][5])
print (recovery, aids)

f = open("/home/jason/Documents/mysample.txt", "r", encoding="utf-8")
elmo.ElmoEmbedder.embed_file(elmo_ins, input_file=f,output_file_path="/home/jason/Documents/elmo_layers2.hdf5")
# Out:
# 01/22/2019 16:17:05 - INFO - allennlp.commands.elmo -   Processing sentences.
# 0it [00:00, ?it/s]
# 0.7705785483121872 0.7645671665668488
# 2it [00:00,  3.28it/s]

# %%
import h5py
h5py_file = h5py.File("/home/jason/Documents/elmo_layers.hdf5", 'r')
embedding = h5py_file.get("0")
#assert(len(embedding) == 3) # one layer for each vector
#assert(len(embedding[0]) == 16) # one entry for each word in the source sentence
print("Keys: %s" % h5py_file.keys())
#a_group_key = list(h5py_file.keys())[0]

sentences_t = ["the ravages of AIDS dementia sometimes prompting dramatic recovery of IQ levels and reappearance of lost motor skills .",
"Since then roughly 50 pediatric patients have received the"]
s0= sentences_t[0].split()
# Out:
# Keys: <KeysViewHDF5 ['0', '1', 'sentence_to_index']>

# %%
from allennlp.commands import elmo
elmo_ins = elmo.ElmoEmbedder(options_file='https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway_5.5B/elmo_2x4096_512_2048cnn_2xhighway_5.5B_options.json', 
    weight_file='https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway_5.5B/elmo_2x4096_512_2048cnn_2xhighway_5.5B_weights.hdf5'
                   )

bridging_path= "/home/jason/Documents/bridging_files/"

def create_elmo_embeddings_from_file(input_file,output_name):
    #input_file = "/home/jason/Documents/mysample.txt"
    output_file = f'{bridging_path}docs_as_sents/tensors/{output_name}.hdf5'
    f = open(input_file, "r", encoding="utf-8")
    elmo.ElmoEmbedder.embed_file(elmo_ins, input_file=f,output_file_path = output_file)
# Out:
# 01/22/2019 17:44:54 - INFO - allennlp.commands.elmo -   Initializing ELMo.

# %%
files_paths= ["/home/jason/Documents/bridging_files/docs_as_sents/1465.txt","/home/jason/Documents/bridging_files/docs_as_sents/1163.txt","/home/jason/Documents/bridging_files/docs_as_sents/1423.txt","/home/jason/Documents/bridging_files/docs_as_sents/1448.txt","/home/jason/Documents/bridging_files/docs_as_sents/1101.txt","/home/jason/Documents/bridging_files/docs_as_sents/1150.txt","/home/jason/Documents/bridging_files/docs_as_sents/1121.txt","/home/jason/Documents/bridging_files/docs_as_sents/1066.txt","/home/jason/Documents/bridging_files/docs_as_sents/1353.txt","/home/jason/Documents/bridging_files/docs_as_sents/1404.txt","/home/jason/Documents/bridging_files/docs_as_sents/1123.txt","/home/jason/Documents/bridging_files/docs_as_sents/1148.txt","/home/jason/Documents/bridging_files/docs_as_sents/1215.txt","/home/jason/Documents/bridging_files/docs_as_sents/1315.txt","/home/jason/Documents/bridging_files/docs_as_sents/1041.txt","/home/jason/Documents/bridging_files/docs_as_sents/1232.txt","/home/jason/Documents/bridging_files/docs_as_sents/1424.txt","/home/jason/Documents/bridging_files/docs_as_sents/1367.txt","/home/jason/Documents/bridging_files/docs_as_sents/1310.txt","/home/jason/Documents/bridging_files/docs_as_sents/1044.txt","/home/jason/Documents/bridging_files/docs_as_sents/1004.txt","/home/jason/Documents/bridging_files/docs_as_sents/2454.txt","/home/jason/Documents/bridging_files/docs_as_sents/1053.txt","/home/jason/Documents/bridging_files/docs_as_sents/1388.txt","/home/jason/Documents/bridging_files/docs_as_sents/1100.txt","/home/jason/Documents/bridging_files/docs_as_sents/1264.txt","/home/jason/Documents/bridging_files
hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1215.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1153.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1367.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1424.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1017.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1148.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1353.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1448.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1004.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1310.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1315.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1100.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1121.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1137.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1387.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1123.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1404.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1163.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1066.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1324.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1313.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1232.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors2454.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1436.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1160.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1450.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1150.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1172.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1101.hdf5"]
for file in files_paths:
    h5py_file = h5py.File(file, 'r')
    #embedding = h5py_file.get("0")
    data = list(h5py_file["0"])
    for sent_i in 
    
for x in range(len(data[0])):
    print (s0[x],data[0][x])

# %%
layer = 0
files_paths= ["/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1455.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1044.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1423.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1146.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1174.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1397.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1200.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1053.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1428.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1284.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1041.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1264.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1388.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1327.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1443.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1435.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1465.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1473.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1094.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1379.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1298.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1215.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1153.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1367.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1424.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1017.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1148.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1353.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1448.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1004.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1310.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1315.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1100.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1121.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1137.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1387.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1123.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1404.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1163.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1066.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1324.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1313.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1232.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors2454.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1436.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1160.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1450.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1150.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1172.hdf5","/home/jason/Documents/bridging_files/docs_as_sents/tensors/tensors1101.hdf5"]

outputmatrix = open(f'{bridging_path}outputmatrix', "w", encoding="utf-8")
delimitator= " "
file = files_paths[0]
file_name = file[66:70] # file identifier in file_name

h5py_file = h5py.File(file, 'r')
nro_sents = len(h5py_file.keys())
for sent_i in range(nro_sents):
    sentence = list(h5py_file[str(sent_i)])
    nro_words= len(sentence[layer]) #  anyway all layers have the same nro words
    for word_j in range(nro_words):
        word_embbeding=  sentence[layer][word_j]
        print (word_embbeding)
        outputmatrix.write(file_name)
        outputmatrix.write(delimitator)
        outputmatrix.write(str(sent_i))
        outputmatrix.write(delimitator)
        outputmatrix.write(' '.join(str(x) for x in word_embbeding))
        outputmatrix.write("\n")
outputmatrix.close()
# Out:
# [-0.45971453 -0.6261169  -0.34094578 ...  0.09659612  0.04696405
#   0.6307044 ]
# [-0.38238043 -0.16547747  0.030922   ... -0.27096274  0.10054415
#   0.09335169]
# [ 0.00996799  0.01083953 -0.07968318 ... -0.01436361 -0.0798783
#   0.0051978 ]
# [-0.10260962  0.26183024  0.45106    ... -0.12090024  0.02721968
#  -0.836383  ]
# [ 0.06595892  0.0784817   0.01674401 ... -0.01064998 -0.09568267
#   0.03774387]
# [ 0.00996799  0.01083953 -0.07968318 ... -0.01436361 -0.0798783
#   0.0051978 ]
# [ 0.17024504  0.10339425  0.04465909 ...  0.28139108 -0.24709405
#  -0.0752248 ]
# [ 0.2565068   0.32710478  0.06994912 ... -0.02076162 -0.01330744
#   0.19216616]
# [ 1.6656518e-04  3.2371935e-03  3.4332392e-01 ...  9.8351344e-02
#  -3.1321460e-01 -1.7759980e-01]
# [-0.26371506  0.12783715  0.22227454 ... -0.07806356 -0.08793723
#  -0.08761961]
# [ 0.24499612 -0.4302806  -0.01550993 ...  0.5995983   0.0267355
#   0.21980181]
# [ 0.09883016 -0.22641753  0.19245099 ...  1.0138949  -0.3174794
# ...

# %%
sentence = list(h5py_file[str(0)])
print (len(sentence[0]))
# Out:
# 23

# %%
file = files_paths[0]
file.index("tensors")
# Out:
# '1455'

# %%
from itertools import groupby
from operator import itemgetter

data = [ 1, 4,5,6, 10, 15,16,17,18, 22, 25,26,27,28]
mylist = [[269, 270, 271, 272, 273, 274, 277, 278, 280],[51, 52, 53, 54, 55, 56, 57],[411, 412, 413, 414, 415, 417, 418],[239, 240, 242, 246, 248, 250],[286, 287, 288, 289, 290, 291],[341, 342, 343, 346, 349, 350],[263, 264, 265, 266, 267],[309, 317, 318, 319, 321],[329, 330, 331, 332, 333],[554, 555, 556, 557, 559],[621, 622, 623, 624, 625],[632, 633, 634, 636, 637],[58, 59, 60, 61],[173, 174, 175, 176],[229, 231, 232, 233],[534, 535, 536, 537],[542, 543, 544, 545],[592, 593, 594, 595],[627, 628, 629, 630],[0, 1, 2],[43, 44, 46],[112, 114, 118],[115, 116, 117],[187, 188, 189],[215, 217, 219],[220, 221, 222],[251, 253, 257],[279, 282, 283],[294, 295, 296],[316, 322, 323],[325, 326, 327],[372, 373, 374],[387, 388, 389],[400, 401, 402],[419, 421, 439],[423, 424, 425],[435, 438, 440],[465, 466, 467],[533, 541, 546],[538, 539, 540],[610, 611, 612],[649, 650, 651],[4, 5],[8, 9],[23, 25],[26, 28],[36, 37],[67, 72],[79, 80],[81, 82],[96, 98],[106, 113],[120, 121],[131, 132],[138, 139],[141, 142],[144, 149],[155, 156],[163, 165],[178, 179],[190, 191],[192, 193],[197, 198],[206, 209],[224, 225],[227, 228],[254, 255],[256, 260],[258, 259],[299, 300],[311, 314],[334, 335],[345, 347],[366, 368],[369, 370],[375, 376],[380, 381],[396, 398],[407, 408],[426, 432],[428, 429],[436, 437],[443, 444],[447, 448],[451, 452],[459, 460],[463, 464],[469, 470],[471, 472],[491, 492],[499, 500],[523, 524],[525, 547],[550, 551],[552, 553],[563, 564],[565, 566],[567, 568],[577, 578],[580, 581],[583, 585],[586, 587],[590, 591],[598, 599],[600, 602],[605, 606],[616, 619],[639, 640],[657, 658],[661, 662]]
def itworks(data):
    for k, g in groupby(enumerate(data), lambda (i, x): i-x):
        print map(itemgetter(1), g)
itworks(data)

# %%
elmo_ins = elmo.ElmoEmbedder(options_file='https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway_5.5B/elmo_2x4096_512_2048cnn_2xhighway_5.5B_options.json', 
    weight_file='https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway_5.5B/elmo_2x4096_512_2048cnn_2xhighway_5.5B_weights.hdf5'
                            )
row = "And the Communists ' did try ."
tokens= row.split()
vectors = elmo_ins.embed_sentence(tokens)
# Out:
# 01/31/2019 17:22:31 - INFO - allennlp.commands.elmo -   Initializing ELMo.

# %%
output = []
for word_embbeding in vectors[layer]:
    emb_txt= word_embbeding.tolist()
    print (type(emb_txt),type(emb_txt),type(word_embbeding),type(vectors[layer]))
    output.append(word_embbeding)
output[0]

output = []
output += [word_embbeding.tolist() for word_embbeding in vectors[layer]]
output[0]
# Out:
# <class 'list'> <class 'list'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# <class 'list'> <class 'list'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# <class 'list'> <class 'list'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# <class 'list'> <class 'list'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# <class 'list'> <class 'list'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# <class 'list'> <class 'list'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# <class 'list'> <class 'list'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# [-0.20726308226585388,
#  0.08870576322078705,
#  -0.8964043855667114,
#  0.2720193862915039,
#  -0.18103420734405518,
#  -0.07547830790281296,
#  0.15856564044952393,
#  0.11253528296947479,
#  -0.08798246085643768,
#  -0.2703022360801697,
#  0.33306217193603516,
#  -0.1710258573293686,
#  -0.04082026332616806,
#  -0.25421229004859924,
#  -0.30532437562942505,
#  0.09351715445518494,
#  -0.4184699058532715,
# ...
